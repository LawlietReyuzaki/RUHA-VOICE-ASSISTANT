# %%
import zipfile as z
import os

target = "Assignment 7 part 1-20211201T161419Z-001.zip"

root = z.ZipFile(target)
print(root) 
root.extractall()
root.close()

dirpath=""
dirnames = []
filenames = []
i = 0;

parent = "After Ext"
os.mkdir(parent)

for (dirpath, dirnames, filenames) in os.walk("Assignment 7 part 1/"):
	
	i = i+1

	#print("dirpat: ", dirpath)
	#print("filenames: ", filenames)

	#print ("value of counter is", i)
	for word in filenames:
		print(word)
		
		Str = word.replace('.zip', '')
		path = os.path.join(parent,Str)
		
		mode = 0o777
		os.mkdir(path, mode)
	
		target = dirpath+'/'+ word
		root = z.ZipFile(target)
		root.extractall(parent+'/'+Str)
# Out:
# <zipfile.ZipFile filename='Assignment 7 part 1-20211201T161419Z-001.zip' mode='r'>
# i200934.zip
# i200627.zip
# 20I-0916.zip
# i191668.zip
# i200818.zip
# i191873.zip
# i202337.zip
# i200826.zip
# i200988.zip
# i200478.zip
# i201754.zip
# i201799.zip
# i200931.zip
# i201877.zip
# i202707.zip
# i200605(1).zip
# i202444.zip
# i1202367(1).zip
# i200915.zip
# i201843.zip
# i202459.zip
# i200401.zip
# i201818.zip
# i191700.zip
# i201867.zip
# i200570.zip
# i20_0985-J.zip
# i200471.zip
# i202402.zip
# i200657.zip
# i191859.zip
# i201805-K.zip
# i200471(1).zip
# i200936.zip
# i202391.zip
# i1202367.zip
# i200478(1).zip
# i201843(1).zip
# i201836.zip
# i200974.zip
# i200783 J.zip
# i191881.zip
# i191884.zip
# i20-2704.zip
# i191742.zip
# i200685.zip
# i201835.zip
# i200915_J.zip
# i200823.zip
# i200429.zip
# i191770.zip
# i202435.zip
# i200774.zip
# i200776.zip
# i200765_K.zip
# i200605.zip
# i20-1879.zip
# i201877(1).zip
# i200452.zip
# i201753.zip
# i200572.zip
# i201824.zip
# ...

# %%
import os
import shutil

#os.mkdir("Combine")
for i in os.listdir("After Ext"):
	#print (i)
	for (filedir, subdir, filenames) in os.walk("After Ext/" + i):
		
		if(len(subdir) != 0):
			
			if(len(subdir) == 1):
				folder = str(subdir[0])
				#print ("value of folder : ", folder)
				roll = str(subdir[0])
				roll = roll.replace('i', '')
				roll = roll.replace('-', '')
				#print("type: ", type(name)) 
				print("After Ext/" + i + '/' + folder)
				#rename items 
				#print("value of i : ", i) 
				for x in os.listdir("After Ext/" + i + '/' + folder):
					print(x)
					old_name = x
					new_name = roll + '_' + old_name
					
					os.rename("After Ext/" + i + '/' + folder + '/' + x,"After Ext/" + i + '/' + folder + '/' + new_name)
					print("Renanmed at:", "After Ext/" + i + '/' + folder + '/' + new_name)
					
			
			else:
				for x in subdir:
					if(x == '__MACOSX'):
						continue
					folder = str(subdir[0])
					roll = str(subdir[0])
					roll = roll.replace('i', '')
					roll = roll.replace('-', '')
					#print("type: ", type(name)) 
					
					for y in os.listdir("After Ext/" + i + '/' + folder):
						old_name = y
						new_name = roll + '_' + old_name
						
						os.rename("After Ext/" + i + '/' + folder + '/' + y,"After Ext/" + i + '/' + folder + '/' + new_name)
						print("Renanmed at:", "After Ext/" + i + '/' + folder + '/' + new_name) 
		#print (subdir)
		
		if(len(subdir) == 0):
				
				print("\n\n\n\n\n\n\n Zip files with no folders:" )
				
				for x in os.listdir("After Ext/"+i):
					
					old_name = x
					roll = i.replace("i", "")
					new_name = roll + '_' + old_name
					
					os.rename("After Ext/"+i+'/'+x, "After Ext/"+i+'/'+new_name)
					print("renamed")
		
		break
# Out:
#  Zip files with no folders:
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# ...

# %%
import shutil, os

counter = 0 
for (dirpath, dirnames, filenames) in os.walk("After Ext/"):
	
	
	#print("dirpath:", dirpath)
	#print("dirnames:", dirnames)
	#print("filenames:", filenames)
	
#After Ext/i202435/i20435/file.mp3
	os.mkdir("Combine")
	
	for x in dirnames:
		for (dirpath, dirnames, filenames) in os.walk("After Ext/"+x):
		
			if(len(dirnames) == 0):
			
				for i in filenames:
					temp_path = "After Ext/" + x +'/' + i
					print ("contain only files")
					shutil.copy(temp_path, "Combine")
			else:
				
				for y in dirnames:
				
					if(y == "__MACOSX" or y == "Record"):
						continue
					
					for i in os.listdir("After Ext/"+x+ '/' +y):
						temp_path = "After Ext/" + x +'/' + y + '/' + i
						print("contain folders")
						shutil.copy(temp_path, "Combine")
					
			break
			
			
	
	
	break
	
	
	
	'''
	for x in dirnames:
		folder = dirpath +x+'/'
		print("the path is: ", folder)
		for (path, Dir, files) in os.walk(folder):
			for i in files:
				shutil.copy(folder+i, 'Combine')
			
	counter = counter +1
	
	print('\n\n\n Now for the Files.mp3a: \n\n\n', )
	for x in filenames:
		print(dirpath+x)
		shutil.copy(dirpath+x, 'Combine')
		
	
	
	break
	'''

#os.mkdir("test")
#files = ['file1.txt', 'file2.txt', 'file3.txt']
#for f in files:
#   shutil.copy(f, 'dest_folder')
# Out:
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# contain only files
# ...

# %%
import os
import argparse

from pydub import AudioSegment

formats_to_convert = ['.m4a', '.mpeg', '.mp3']

for aformat in formats_to_convert:

	for (dirpath, dirnames, filenames) in os.walk("Combine/"):
		
	    #print("dirpath:", dirpath)
	    #print("dirnames:", dirnames)
	    #print("filenames:", filenames)

		for filename in filenames:
			if filename.endswith(tuple(aformat)):
				filepath = dirpath + '/' + filename
				(path, file_extension) = os.path.splitext(filepath)
				file_extension_final = file_extension.replace('.', '')
				try:
					track = AudioSegment.from_file(filepath,
						file_extension_final)
					wav_filename = filename.replace(file_extension_final, 'wav')
					wav_path = dirpath + '/' + wav_filename
					print('CONVERTING: ' + str(filepath))
					file_handle = track.export(wav_path, format='wav')
					os.remove(filepath)
				except:
					print("ERROR CONVERTING " + str(filepath))
# Out:
# CONVERTING: Combine//200803_T.V unmute karo.m4a
# CONVERTING: Combine//200803_T.V chlao.m4a
# CONVERTING: Combine//200460_Ruha T.V par cartoon network lagao.m4a
# CONVERTING: Combine//200605_Pichla channel lagao.m4a
# CONVERTING: Combine//200471(1)_Bathroom ka Bulb jalao.m4a
# CONVERTING: Combine//200605_TV band karo.m4a
# CONVERTING: Combine//I202414_Agla Gaana lagao.mp3.m4a
# CONVERTING: Combine//200429_Ruha Bethaq ki Light jalao.m4a
# CONVERTING: Combine//202483_Ruha Lounge ka Bulb off karo.m4a
# CONVERTING: Combine//200429_Ruha T.V par jeo news lagao.m4a
# CONVERTING: Combine//202707_Ruha T.V chlao.m4a
# CONVERTING: Combine//201836_T.V ki awaz slow karo.m4a
# CONVERTING: Combine//Ruha T.V off karo.m4a
# CONVERTING: Combine//200572_A.C chlao.m4a
# CONVERTING: Combine//20I0916_Ruha Bedroom ka Bulb off karo.m4a
# CONVERTING: Combine//200605_Gaaney lagao.m4a
# CONVERTING: Combine//202404_bethak ka bulb on karo.m4a
# CONVERTING: Combine//1202367_T.V par ARY Digital lagao.m4a
# ...

# %%
import os

for name in os.listdir("Combine"):
    y = name
    name = name.replace('Ruha', '')
    name = name.replace('ruha', '')
    name = name.replace('A.C.', 'A.C')
    name = name.replace('AC', 'A.C')
    name = name.replace('kero', 'karo')
    name = name.replace('chalao ', 'chlao')
    name = name.replace('Karo', 'karo')
    name = name.replace('Chlao', 'chlao')
    name = name.replace('Tez', 'tez')
    name = name.replace('Ac', 'A.C')            
    name = name.replace('A. C', 'A.C')
    name = name.replace('a.c', 'A.C')
    name = name.replace(' lounge', 'Lounge')
    name = name.replace('bnd', 'band')
    name = name.replace('kro', 'karo')
    name = name.replace('chalo', 'chlao')
    name = name.replace('karo ', 'karo')
    name = name.replace('chalao', 'chlao')
    name = name.replace('ac', 'A.C')
    name = name.replace('A C', 'A.C')
    name = name.replace('agla', 'Agla')
    name = name.replace('Channel', 'channel')
    name = name.replace('gaana', 'Gaana')
    name = name.replace('lagao ', 'lagao')
    name = name.replace('Gana', 'Gaana')
    name = name.replace('gana', 'Gaana')
    name = name.replace('ganna', 'Gaana')
    name = name.replace('song', 'Song')
    name = name.replace('bathroom', 'Bathroom')
    name = name.replace('baithak', 'Bethaq')
    name = name.replace('bulb', 'Bulb')
    name = name.replace('Baithak', 'Bethaq')
    name = name.replace('Ka', 'ka')
    name = name.replace('Jalao', 'jalao')
    name = name.replace('Kru', 'karo')
    name = name.replace('kar do', 'karo')
    name = name.replace('Band', 'band')
    name = name.replace('Off', 'off')
    name = name.replace('Whashroom', 'Washroom')
    name = name.replace('washrrom', 'Washroom')
    name = name.replace('Washrooom', 'Washroom')
    name = name.replace(' room', '')
    name = name.replace('washroom', 'Washroom')
    name = name.replace('light', 'Light')
    name = name.replace('Ki', 'ki')
    name = name.replace('tv', 'T.V')
    name = name.replace('TV', 'T.V')
    name = name.replace('Tv', 'T.V')
    name = name.replace('wahroom', 'Washroom')
    name = name.replace('Wahroom', 'Washroom')
    name = name.replace('un mute', 'unmute')
    name = name.replace('hbo', 'HBO')
    name = name.replace('ary digital', 'ARY Digital')
    name = name.replace('ary news', 'ARY News')
    name = name.replace(' per ', ' par ')
    name = name.replace('T.V T.V', 'T.V')
    name = name.replace('Q T.V', 'Q-TV')
    name = name.replace('QT.V', 'Q-TV')
    name = name.replace('qT.V', 'Q-TV')
    name = name.replace('q T.V', 'Q-TV')
    name = name.replace('Q-T.V', 'Q-TV')
    name = name.replace('kitchen', 'Kitchen')
    name = name.replace('Samaa', 'samaa')
    name = name.replace('umute', 'unmute')
    name = name.replace('T. V', 'T.V')
    name = name.replace('masla T.V', 'Masla TV')
    name = name.replace('Masala', 'Masla')
    name = name.replace('jaao', 'jeo')
    name = name.replace('lagai', 'lagao')
    name = name.replace('algao', 'lagao')
    name = name.replace('masala T.V', 'Masla TV')
    name = name.replace('T.V par masala lagao', 'T.V par Masla TV lagao')
    name = name.replace('Masla T.V', 'Masla TV')
    name = name.replace('hum T.V', 'HUM TV')
    name = name.replace('Hum T.V', 'HUM TV')
    name = name.replace('News', 'news')
    name = name.replace('t.v', 'T.V')
    name = name.replace('RUha ', '')
    name = name.replace('RUha', '')
    name = name.replace('lounge', 'Lounge')
    name = name.replace('  ', ' ')
    name = name.replace('garage', 'Garage')
    name = name.replace('bethaq', 'Bethaq')
    name = name.replace('tezz', 'tez')
    name = name.replace('bund', 'band')
    name = name.replace('karo1', 'karo')
    name = name.replace('bedroom', 'Bedroom')
    name = name.replace('Bethak', 'Bethaq')
    name = name.replace('bethak', 'Bethaq')
    name = name.replace('gaaney', 'Gaaney')
    name = name.replace('Gaanay', 'Gaaney')
    name = name.replace('lgao', 'lagao')
    name = name.replace('ganney', 'Gaaney')
    name = name.replace('Ganney', 'Gaaney')
    name = name.replace('next', 'Next')
    name = name.replace('pichla', 'Pichla')
    name = name.replace('previous', 'Previous')
    name = name.replace('q-T.V', 'Q-TV')
    name = name.replace('jao', 'jeo')
    name = name.replace('Bedrooom', 'Bedroom')
    name = name.replace('jalao ', 'jalao')
    name = name.replace('taez', 'tez')
    name = name.replace('tex', 'tez')
    name = name.replace('awaaz', 'awaz')
    name = name.replace('kam', 'kum')
    name = name.replace('kaam', 'kum')
    name = name.replace('zada', 'ziada')
    name = name.replace('ziyada', 'ziada')
    name = name.replace('zyada', 'ziada')
    name = name.replace('Volume', 'volume')
    name = name.replace('kumm', 'kum')
    name = name.replace('digital', 'Digital')
    name = name.replace('Cartoon', 'cartoon')
    name = name.replace('Network', 'network')
    name = name.replace('T.V.', 'T.V')
    name = name.replace('On', 'on')
    name = name.replace('bupb', 'Bulb')
    name = name.replace('ku', 'ki')
    name = name.replace('Lagao', 'lagao')
    name = name.replace('zaida', 'ziada')
    name = name.replace('kim', 'kum')
    name = name.replace('geo', 'jeo')
    name = name.replace('jaalao', 'jalao')
    name = name.replace('kichen', 'Kitchen')
    name = name.replace('kicthen', 'Kitchen')
    name = name.replace('Garaga', 'Garage')
    name = name.replace('Song ', 'Songs ')
    name = name.replace('Songslagao', 'Song lagao')
    print(name)
    os.rename("Combine/"+y, "Combine/"+name)
# Out:
# 200685_Kitchen ki Light band karo.wav
# 202438_ T.V ki awaz ahista karo.wav
# Assgnment 7 PAI_Washroom ki Light on karo.wav
# 202404_T.V mute karo.wav
# 201877_ Lounge ki Light on karo.wav
# 201836_T.V par Q-TV lagao.wav
# 200570_ Bethaq ki Light jalao.wav
# 200931_ Washroom ka Bulb band karo.wav
# 200767_Washroom ka Bulb off karo.wav
# 200627_Garage ki Light off karo.wav
# 200460_ Bethaq ki Light jalao.wav
# 191668_ Bathroom ki Light off karo.wav
# 191884_A.C off karo.wav
# 200823_ Bathroom ka Bulb jalao.aA.C
# 191859_T.V ka volume slow karo.wav
# 202435_ Bedroom ki Light on karo.wav
# 200934_ Bethaq ka Bulb on karo.wav
# 200627_Washroom ki Light band karo.wav
# 200627_Bethaq ka Bulb jalao.wav
# 202483_ T.V ka volume tez karo.wav
# 202459_Bathroom ka Bulb jalao.wav
# Assgnment 7 PAI_Bethaq ki Light on karo.wav
# 202444_Washroom ki Light jalao.wav
# 201835_ A.C tez karo.mpeg
# 201824_ T.V par Masla TV lagao.wav
# 200934_ Agla Gaana lagao.wav
# 200471_Washroom ki Light jalao.wav
# ...

# %%
import os, shutil

classes = ['Previous Gaana lagao', 'Garage ki Light on karo', 'T.V unmute karo', 'Bethaq ki Light jalao', 'T.V chlao', 'T.V par HBO lagao', 'Kitchen ki Light on karo', 'Bethaq ka Bulb jalao', 'Washroom ka Bulb jalao', 'Bethaq ka Bulb off karo', 'A.C fast karo', 'Kitchen ki Light off karo', 'Garage ki Light band karo', 'A.C on karo', 'T.V ki awaz tez karo', 'A.C ahista karo', 'T.V ka volume ahista karo', 'T.V ki awaz slow karo', 'Washroom ki Light jalao', 'T.V par samaa news lagao', 'Bethaq ki Light band karo', 'Bedroom ka Bulb off karo', 'A.C chlao', 'T.V ki awaz ahista karo', 'Lounge ka Bulb on karo', 'Agla Gaana lagao', 'Lounge ka Bulb band karo', 'Agla channel lagao', 'Previous channel lagao', 'Songs lagao', 'T.V off karo', 'Garage ka Bulb band karo', 'Bathroom ki Light on karo', 'Bethaq ka Bulb on karo', 'T.V par discovery lagao', 'Kitchen ka Bulb jalao', 'Garage ki Light jalao', 'T.V par cartoon network lagao', 'T.V band karo', 'Bedroom ki Light jalao', 'T.V par Masla TV  lagao', 'Lounge ki Light band karo', 'Lounge ka Bulb jalao', 'Kitchen ki Light jalao', 'Agla Song lagao', 'Washroom ka Bulb band karo', 'Next channel lagao', 'Bedroom ka Bulb jalao', 'Bedroom ki Light on karo', 'Kitchen ka Bulb off karo', 'A.C off karo', 'Bedroom ka Bulb band karo', 'Washroom ki Light band karo', 'Washroom ki Light on karo', 'Washroom ka Bulb on karo', 'T.V ka volume slow karo', 'Lounge ka Bulb off karo', 'A.C slow karo', 'Bathroom ki Light jalao', 'T.V ka volume ziada karo', 'Previous Song lagao', 'Lounge ki Light jalao', 'Bathroom ki Light band karo', 'Garage ka Bulb jalao', 'Bathroom ka Bulb band karo', 'Garage ki Light off karo', 'Pichla Song lagao', 'T.V par Q-TV lagao', 'Bedroom ki Light band karo', 'Next Song lagao', 'Bathroom ka Bulb jalao', 'Lounge ki Light on karo', 'T.V par jeo news lagao', 'Washroom ki Light off karo', 'Bathroom ki Light off karo', 'Washroom ka Bulb off karo', 'T.V ka volume kum  karo', 'Bethaq ki Light off karo', 'Garage ka Bulb on karo', 'Bathroom ka Bulb on karo', 'Bethaq ka Bulb band karo', 'Gaaney lagao', 'T.V ka volume tez karo', 'T.V ki awaz ziada karo', 'Bedroom ka Bulb on karo', 'T.V mute karo', 'Bethaq ki Light on karo', 'T.V par ARY Digital lagao', 'Kitchen ka Bulb band karo', 'Kitchen ka Bulb on karo', 'Lounge ki Light off karo', 'T.V par HUM TV lagao', 'A.C tez karo', 'Bedroom ki Light off karo', 'T.V ki awaz kum karo', 'Next Gaana lagao', 'Garage ka Bulb off karo', 'T.V on karo', 'Pichla Gaana lagao', 'Pichla channel lagao', 'T.V par ARY news lagao', 'Bathroom ka Bulb off karo', 'A.C band karo', 'Kitchen ki Light band karo']

os.mkdir("Classes")
for Class in classes:
	parent = "Classes/"
	mode = 0o777
	
	path = os.path.join(parent,Class)

	os.mkdir(path,mode)
	for name in os.listdir ("Combine"):
		if(name.find(Class) != -1):
			shutil.copy("Combine/" + name, "Classes/"+Class)
			print("file copied: ",name, " ->-> ", "Classes/",Class)
# Out:
# file copied:  200627_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  201824_ Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  200974_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  201799_Previous Gaana lagao.mp3  ->->  Classes/ Previous Gaana lagao
# file copied:  191668_ Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  200471(1)_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  201753_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  201754_Previous Gaana lagao.mp3  ->->  Classes/ Previous Gaana lagao
# file copied:  200988_ Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  200572_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# file copied:  202704_Previous Gaana lagao.wav  ->->  Classes/ Previous Gaana lagao
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

knn = pd.DataFrame()


for Class_name in os.listdir("Classes"):
    
    path_inside = "Classes/" + Class_name
    
    Recordings = []
    
    for audio in os.listdir(path_inside):
        Recordings.append(audio)
    
    if(len(Recordings) == 1):
        continue
    if(len(Recordings) == 0):
        continue
    
    #print (len(Recordings))
    knn[Class_name] = Recordings[0:40]

#knn.apply(LabelEncoder().fit_transform)
#knn.apply(LableEncoder())
knn.head(7)
# Out:
#                A.C band karo               Washroom ka Bulb on karo  \
# 0  202435_ A.C band karo.wav   191873_ Washroom ka Bulb on karo.wav
# 1  191700_ A.C band karo.wav  201835_ Washroom ka Bulb on karo.mpeg
# 2   201836_A.C band karo.wav    201799_Washroom ka Bulb on karo.mp3
# 3  191668_ A.C band karo.wav   1202367_Washroom ka Bulb on karo.wav
# 4   201753_A.C band karo.wav   191668_ Washroom ka Bulb on karo.wav
# 5   201878_A.C band karo.wav    200572_Washroom ka Bulb on karo.wav
# 6   200627_A.C band karo.wav    191873_Washroom ka Bulb on karo.wav
#
#                       T.V on karo                Previous Gaana lagao  \
# 0          200915_T.V on karo.wav     200627_Previous Gaana lagao.wav
# 1          200818_T.V on karo.mp3    201824_ Previous Gaana lagao.wav
# 2  voce recorder_ T.V on karo.wav     200974_Previous Gaana lagao.wav
# 3          200605_T.V on karo.wav     201799_Previous Gaana lagao.mp3
# 4         201877_ T.V on karo.wav    191668_ Previous Gaana lagao.wav
# ...

# %%
knn = pd.DataFrame()

i =0
for Class_name in os.listdir("Classes"):
    
    path_inside = "Classes/" + Class_name
    
    Recordings = []
    
    for audio in os.listdir(path_inside):
        Recordings.append(path_inside+'/'+audio)
    
    if(len(Recordings) == 1):
        continue
    if(len(Recordings) == 0):
        continue
    
    #print (len(Recordings))
    knn[i] = Recordings[0:40]
    i=i+1

#knn.apply(LabelEncoder().fit_transform)
#knn.apply(LableEncoder())
knn.head(7)
# Out:
#                                                 0   \
# 0  Classes/A.C band karo/202435_ A.C band karo.wav
# 1  Classes/A.C band karo/191700_ A.C band karo.wav
# 2   Classes/A.C band karo/201836_A.C band karo.wav
# 3  Classes/A.C band karo/191668_ A.C band karo.wav
# 4   Classes/A.C band karo/201753_A.C band karo.wav
# 5   Classes/A.C band karo/201878_A.C band karo.wav
# 6   Classes/A.C band karo/200627_A.C band karo.wav
#
#                                                   1   \
# 0  Classes/Washroom ka Bulb on karo/191873_ Washr...
# 1  Classes/Washroom ka Bulb on karo/201835_ Washr...
# 2  Classes/Washroom ka Bulb on karo/201799_Washro...
# 3  Classes/Washroom ka Bulb on karo/1202367_Washr...
# 4  Classes/Washroom ka Bulb on karo/191668_ Washr...
# 5  Classes/Washroom ka Bulb on karo/200572_Washro...
# 6  Classes/Washroom ka Bulb on karo/191873_Washro...
#
#                                                   2   \
# 0         Classes/T.V on karo/200915_T.V on karo.wav
# ...

# %%
import pandas as pd
import os
import numpy as np
knn = pd.DataFrame()

classes = ['Previous Gaana lagao', 'Garage ki Light on karo', 'T.V unmute karo', 'Bethaq ki Light jalao', 'T.V chlao', 'T.V par HBO lagao', 'Kitchen ki Light on karo', 'Bethaq ka Bulb jalao', 'Washroom ka Bulb jalao', 'Bethaq ka Bulb off karo', 'A.C fast karo', 'Kitchen ki Light off karo', 'Garage ki Light band karo', 'A.C on karo', 'T.V ki awaz tez karo', 'A.C ahista karo', 'T.V ka volume ahista karo', 'T.V ki awaz slow karo', 'Washroom ki Light jalao', 'T.V par samaa news lagao', 'Bethaq ki Light band karo', 'Bedroom ka Bulb off karo', 'A.C chlao', 'T.V ki awaz ahista karo', 'Lounge ka Bulb on karo', 'Agla Gaana lagao', 'Lounge ka Bulb band karo', 'Agla channel lagao', 'Previous channel lagao', 'Songs lagao', 'T.V off karo', 'Garage ka Bulb band karo', 'Bathroom ki Light on karo', 'Bethaq ka Bulb on karo', 'T.V par discovery lagao', 'Kitchen ka Bulb jalao', 'Garage ki Light jalao', 'T.V par cartoon network lagao', 'T.V band karo', 'Bedroom ki Light jalao', 'T.V par Masla TV  lagao', 'Lounge ki Light band karo', 'Lounge ka Bulb jalao', 'Kitchen ki Light jalao', 'Agla Song lagao', 'Washroom ka Bulb band karo', 'Next channel lagao', 'Bedroom ka Bulb jalao', 'Bedroom ki Light on karo', 'Kitchen ka Bulb off karo', 'A.C off karo', 'Bedroom ka Bulb band karo', 'Washroom ki Light band karo', 'Washroom ki Light on karo', 'Washroom ka Bulb on karo', 'T.V ka volume slow karo', 'Lounge ka Bulb off karo', 'A.C slow karo', 'Bathroom ki Light jalao', 'T.V ka volume ziada karo', 'Previous Song lagao', 'Lounge ki Light jalao', 'Bathroom ki Light band karo', 'Garage ka Bulb jalao', 'Bathroom ka Bulb band karo', 'Garage ki Light off karo', 'Pichla Song lagao', 'T.V par Q-TV lagao', 'Bedroom ki Light band karo', 'Next Song lagao', 'Bathroom ka Bulb jalao', 'Lounge ki Light on karo', 'T.V par jeo news lagao', 'Washroom ki Light off karo', 'Bathroom ki Light off karo', 'Washroom ka Bulb off karo', 'T.V ka volume kum  karo', 'Bethaq ki Light off karo', 'Garage ka Bulb on karo', 'Bathroom ka Bulb on karo', 'Bethaq ka Bulb band karo', 'Gaaney lagao', 'T.V ka volume tez karo', 'T.V ki awaz ziada karo', 'Bedroom ka Bulb on karo', 'T.V mute karo', 'Bethaq ki Light on karo', 'T.V par ARY Digital lagao', 'Kitchen ka Bulb band karo', 'Kitchen ka Bulb on karo', 'Lounge ki Light off karo', 'T.V par HUM TV lagao', 'A.C tez karo', 'Bedroom ki Light off karo', 'T.V ki awaz kum karo', 'Next Gaana lagao', 'Garage ka Bulb off karo', 'T.V on karo', 'Pichla Gaana lagao', 'Pichla channel lagao', 'T.V par ARY news lagao', 'Bathroom ka Bulb off karo', 'A.C band karo', 'Kitchen ki Light band karo']


knn = pd.DataFrame()

i =0
for Class_name in os.listdir("Classes"):
    
    path_inside = "Classes/" + Class_name
    
    Recordings = []
    
    for audio in os.listdir(path_inside):
        Recordings.append(path_inside+'/'+audio)
    
    if(len(Recordings) == 1):
        continue
    
    #print (len(Recordings))
    knn[i] = Recordings[0:40]
    i=i+1

#knn.apply(LabelEncoder().fit_transform)
#knn.apply(LableEncoder())
knn.head(7)


#!pip install librosa
#!pip install numba

import librosa
import soundfile as sf
#import numpy as np

list1 =[]
list2 = []
arr = np.array([])

for i in range(0, 100):
	arr = knn[i].tolist()

	for x in arr:
		audio_path = x
		if(x.find(".mp3") != -1):
			continue
	try:

		X,sample_rate = sf.read(x, dtype='float32')
		MFCC_Features = librosa.feature.mfcc(y=X, sr=sample_rate)
		list1.append(MFCC_Features)
		list2.append(x)
		print (MFCC_Features)

	except:
		print("Error")
		
		
df2 = pd.DataFrame()
df2['paths'] = list2
df2['MFCC'] = list1

print(df2)
# Out:
# /tmp/ipykernel_220424/2917152167.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   knn[i] = Recordings[0:40]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_220424/2917152167.py in <module>
#      34 #!pip install numba
#      35
# ---> 36 import librosa
#      37 import soundfile as sf
#      38 #import numpy as np
#
# ~/.local/lib/python3.8/site-packages/librosa/__init__.py in <module>
#     209 # And all the librosa sub-modules
#     210 from ._cache import cache
# --> 211 from . import core
#     212 from . import beat
#     213 from . import decompose
#
# ...
